# %% [markdown]
# CSVs in Kaggle 'the-movie-dataset'
#
# * credits.csv
# * keywords.csv
# * links.csv
# * links_small.csv
# * movies_metadata.csv
# * ratings.csv
# * ratings_small.csv

# %%
import pandas as pd
movies_metadata_df = pd.read_csv('filtered_movies_metadata.csv', dtype='object')
movies_metadata_df.describe()
# Out:
#         adult                              belongs_to_collection budget  \
# count   45463                                               4491  45463
# unique      2                                               1695   1223
# top     False  {'id': 415931, 'name': 'The Bowery Boys', 'pos...      0
# freq    45454                                                 29  36573
#
#                                genres                     homepage      id  \
# count                           45463                         7779   45463
# unique                           4066                         7670   45433
# top     [{'id': 18, 'name': 'Drama'}]  http://www.georgecarlin.com  141971
# freq                             5000                           12       3
#
#           imdb_id original_language original_title            overview  \
# count       45446             45452          45463               44509
# unique      45416                89          43371               44306
# ...

# %%
movies_metadata_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
credits_df = pd.read_csv('credits.csv')
list(credits_df)
# Out:
# ['cast', 'crew', 'id']

# %%
credits_df.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
keywords_df = pd.read_csv('keywords.csv')
list(keywords_df)
# Out:
# ['id', 'keywords']

# %%
keywords_df.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
links_df = pd.read_csv('links.csv')
list(links_df)
# Out:
# ['movieId', 'imdbId', 'tmdbId']

# %%
links_df.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
links_small_df = pd.read_csv('links_small.csv')
list(links_small_df)
# Out:
# ['movieId', 'imdbId', 'tmdbId']

# %%
links_small_df.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
ratings_df = pd.read_csv('ratings.csv')
list(ratings_df)
# Out:
# ['userId', 'movieId', 'rating', 'timestamp']

# %%
ratings_df.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
ratings_small_df = pd.read_csv('ratings_small.csv')
list(ratings_small_df)
# Out:
# ['userId', 'movieId', 'rating', 'timestamp']

# %%
ratings_df.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
'''
['adult',
 'belongs_to_collection',
 'budget',
 'genres',
 'homepage',
 'id',
 'imdb_id',
 'original_language',
 'original_title',
 'overview',
 'popularity',
 'poster_path',
 'production_companies',
 'production_countries',
 'release_date',
 'revenue',
 'runtime',
 'spoken_languages',
 'status',
 'tagline',
 'title',
 'video',
 'vote_average',
 'vote_count']
 '''
# you can exclude some rows which may not fit in the regression.
filtered_df = movies_metadata_df.drop(['adult',
                       'belongs_to_collection',
                       'genres',
                       'homepage',
                       'id',
                       'imdb_id',
                       'original_language',
                       'original_title',
                       'overview',
                       'poster_path',
                       'production_companies',
                       'production_countries',
                       'release_date',
                       'spoken_languages',
                       'status',
                       'tagline',
                       'title',
                       'video'
                      ], axis=1)

filtered_df.head()
# Out:
#      budget popularity    revenue runtime vote_average vote_count
# 0  30000000  21.946943  373554033    81.0          7.7       5415
# 1  65000000  17.015539  262797249   104.0          6.9       2413
# 2         0    11.7129          0   101.0          6.5         92
# 3  16000000   3.859495   81452156   127.0          6.1         34
# 4         0   8.387519   76578911   106.0          5.7        173

# %%
filtered_df.describe()
# Out:
#        budget popularity revenue runtime vote_average vote_count
# count   45463      45463   45463   45206        45463      45463
# unique   1223      43760    6863     353           92       1820
# top         0        0.0       0    90.0          0.0          1
# freq    36573         66   38055    2556         2998       3265

# %%
import numpy as np
filtered_df = filtered_df.astype(np.float)
scatter_matrix(filtered_df, figsize=(6,6), diagonal='kde')
plt.show()

# %%
filtered_df
# Out:
#            budget  popularity      revenue  runtime  vote_average  vote_count
# 0      30000000.0   21.946943  373554033.0     81.0           7.7      5415.0
# 1      65000000.0   17.015539  262797249.0    104.0           6.9      2413.0
# 2             0.0   11.712900          0.0    101.0           6.5        92.0
# 3      16000000.0    3.859495   81452156.0    127.0           6.1        34.0
# 4             0.0    8.387519   76578911.0    106.0           5.7       173.0
# 5      60000000.0   17.924927  187436818.0    170.0           7.7      1886.0
# 6      58000000.0    6.677277          0.0    127.0           6.2       141.0
# 7             0.0    2.561161          0.0     97.0           5.4        45.0
# 8      35000000.0    5.231580   64350171.0    106.0           5.5       174.0
# 9      58000000.0   14.686036  352194034.0    130.0           6.6      1194.0
# 10     62000000.0    6.318445  107879496.0    106.0           6.5       199.0
# ...

# %%
movies_metadata_df.describe()
# Out:
#         adult                              belongs_to_collection budget  \
# count   45463                                               4491  45463
# unique      2                                               1695   1223
# top     False  {'id': 415931, 'name': 'The Bowery Boys', 'pos...      0
# freq    45454                                                 29  36573
#
#                                genres                     homepage      id  \
# count                           45463                         7779   45463
# unique                           4066                         7670   45433
# top     [{'id': 18, 'name': 'Drama'}]  http://www.georgecarlin.com  141971
# freq                             5000                           12       3
#
#           imdb_id original_language original_title            overview  \
# count       45446             45452          45463               44509
# unique      45416                89          43371               44306
# ...
